# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\\Users\\ASUS\\Downloads\\eda_sample_dataset (2).csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            100 non-null    int64
#  1   Age                   100 non-null    int64
#  2   Gender                100 non-null    str
#  3   Study_Hours           91 non-null     float64
#  4   Attendance            90 non-null     float64
#  5   Marks                 90 non-null     float64
#  6   Department            100 non-null    str
#  7   Internet_Usage_Hours  100 non-null    int64
# dtypes: float64(3), int64(3), str(2)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#        Student_ID         Age  Study_Hours  Attendance       Marks  \
# count  100.000000  100.000000    91.000000   90.000000   90.000000
# mean    50.500000   21.210000     4.912088   78.044444   73.677778
# std     29.011492    1.913773     3.192520   13.219760   18.980669
# min      1.000000   18.000000     1.000000   51.000000   40.000000
# 25%     25.750000   19.750000     2.000000   69.000000   61.000000
# 50%     50.500000   21.000000     5.000000   79.500000   73.500000
# 75%     75.250000   23.000000     7.000000   87.000000   89.750000
# max    100.000000   24.000000    20.000000   99.000000  150.000000
#
#        Internet_Usage_Hours
# count            100.000000
# mean               3.670000
# std                1.938733
# min                1.000000
# 25%                2.000000
# 50%                4.000000
# 75%                5.000000
# max                7.000000

# %%
df.shape
# Out:
# (100, 8)

# %%
df.head()
# Out:
#    Student_ID  Age  Gender  Study_Hours  Attendance  Marks Department  \
# 0           1   24  Female          4.0   90.000000  150.0        ECE
# 1           2   21  Female         20.0   78.044444   61.0         CS
# 2           3   22    Male          3.0   68.000000   62.0       MECH
# 3           4   24  Female          6.0   97.000000   41.0         CS
# 4           5   20    Male          2.0   65.000000   66.0         CS
#
#    Internet_Usage_Hours
# 0                     4
# 1                     3
# 2                     1
# 3                     1
# 4                     2

# %%
df.tail()
# Out:
#     Student_ID  Age  Gender  Study_Hours  Attendance  Marks Department  \
# 95          96   23  Female          1.0        89.0    NaN         CS
# 96          97   21  Female          5.0        95.0   76.0         CS
# 97          98   23    Male          5.0        73.0   65.0        ECE
# 98          99   24    Male          7.0        99.0   92.0        ECE
# 99         100   24    Male          9.0        81.0   62.0         CS
#
#     Internet_Usage_Hours
# 95                     3
# 96                     5
# 97                     4
# 98                     5
# 99                     7

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours', 'Attendance', 'Marks',
#        'Department', 'Internet_Usage_Hours'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Student_ID                int64
# Age                       int64
# Gender                      str
# Study_Hours             float64
# Attendance              float64
# Marks                   float64
# Department                  str
# Internet_Usage_Hours      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# Study_Hours              9
# Attendance              10
# Marks                   10
# Department               0
# Internet_Usage_Hours     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Student_ID              100
# Age                       7
# Gender                    2
# Study_Hours              10
# Attendance               40
# Marks                    49
# Department                4
# Internet_Usage_Hours      7
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# Study_Hours              9
# Attendance              10
# Marks                   10
# Department               0
# Internet_Usage_Hours     0
# dtype: int64

# %%
df[["Study_Hours", "Attendance", "Marks"]].describe()
# Out:
#        Study_Hours  Attendance       Marks
# count   100.000000  100.000000   90.000000
# mean      4.912088   78.044444   73.677778
# std       3.043949   12.534325   18.980669
# min       1.000000   51.000000   40.000000
# 25%       2.000000   69.750000   61.000000
# 50%       4.912088   78.044444   73.500000
# 75%       7.000000   86.250000   89.750000
# max      20.000000   99.000000  150.000000

# %%
df[["Study_Hours", "Attendance", "Marks"]].hist()
# Out:
# array([[<Axes: title={'center': 'Study_Hours'}>,
#         <Axes: title={'center': 'Attendance'}>],
#        [<Axes: title={'center': 'Marks'}>, <Axes: >]], dtype=object)

# %%
#checking for outliers
sns.boxplot(y=df["Study_Hours"])
# Out:
# <Axes: ylabel='Study_Hours'>

# %%
sns.boxplot(y=df["Attendance"])
# Out:
# <Axes: ylabel='Attendance'>

# %%
sns.boxplot(y=df["Marks"])
# Out:
# <Axes: ylabel='Marks'>

# %%
#invalid data
df.loc[df["Marks"]>100,"Marks"]=np.nan

# %%
df["Study_Hours"]=df["Study_Hours"].fillna(df["Study_Hours"].mean())
df["Attendance"]=df["Attendance"].fillna(df["Attendance"].mean())
df["Marks"]=df["Marks"].fillna(df["Marks"].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            100 non-null    int64
#  1   Age                   100 non-null    int64
#  2   Gender                100 non-null    str
#  3   Study_Hours           100 non-null    float64
#  4   Attendance            100 non-null    float64
#  5   Marks                 100 non-null    float64
#  6   Department            100 non-null    str
#  7   Internet_Usage_Hours  100 non-null    int64
# dtypes: float64(3), int64(3), str(2)
# memory usage: 6.4 KB

# %%
#univariate analysis for numerical columns
df.select_dtypes(include="number").columns
# Out:
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance', 'Marks',
#        'Internet_Usage_Hours'],
#       dtype='str')

# %%
df.select_dtypes(include="number").columns.drop("Student_ID")
# Out:
# Index(['Age', 'Study_Hours', 'Attendance', 'Marks', 'Internet_Usage_Hours'], dtype='str')

# %%
numericalcolumns=['Age', 'Study_Hours', 'Attendance', 'Marks', 'Internet_Usage_Hours']
df[numericalcolumns].describe()
# Out:
#               Age  Study_Hours  Attendance       Marks  Internet_Usage_Hours
# count  100.000000   100.000000  100.000000  100.000000            100.000000
# mean    21.210000     4.912088   78.044444   72.820225              3.670000
# std      1.913773     3.043949   12.534325   16.259612              1.938733
# min     18.000000     1.000000   51.000000   40.000000              1.000000
# 25%     19.750000     2.000000   69.750000   61.750000              2.000000
# 50%     21.000000     4.912088   78.044444   72.820225              4.000000
# 75%     23.000000     7.000000   86.250000   86.500000              5.000000
# max     24.000000    20.000000   99.000000   99.000000              7.000000

# %%
#histogram for evry column
import matplotlib.pyplot as plt #kde line shows a smooth estimate of distribution
import seaborn as sns

for col in numericalcolumns:
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
#checking outliers for all numerical columns individually
for col in numericalcolumns:
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
df[numericalcolumns].skew() #checking skewness for all numerical columns helps in finding is the data balanced or not
# Out:
# Age                    -0.041700
# Study_Hours             1.177472
# Attendance             -0.361335
# Marks                  -0.161216
# Internet_Usage_Hours    0.156978
# dtype: float64

# %%
df.select_dtypes(include="str").columns
# Out:
# Index(['Gender', 'Department'], dtype='str')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      60
# Female    40
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="Gender")
plt.show()

# %%
df['Department'].value_counts()
# Out:
# Department
# CS      29
# MECH    29
# IT      25
# ECE     17
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="Department")
plt.show()

# %%
#bivariate analysis study_Hours vs Marks

sns.scatterplot(data=df, x="Study_Hours", y="Marks")
plt.show()

# %%
df["Study_Hours"].corr(df["Marks"])
# Out:
# np.float64(-0.009641875499469292)

# %%
sns.scatterplot(data=df, x="Attendance", y="Marks")
plt.show()

# %%
df["Attendance"].corr(df["Marks"])
# Out:
# np.float64(-0.03772757114489321)

# %%
avg_marks = df.groupby("Department")["Marks"].mean().reset_index()
print(avg_marks)
# Out:
#   Department      Marks
# 0         CS  70.056567
# 1        ECE  72.214144
# 2         IT  71.091236
# 3       MECH  77.429678

# %%
avg_marks = df.groupby("Department")["Marks"].mean().reset_index()

sns.barplot(data=avg_marks, x="Department", y="Marks")
plt.title("Average Marks by Department")
plt.show()

# %%
df.groupby("Gender")["Marks"].mean()
# Out:
# Gender
# Female    72.648034
# Male      72.935019
# Name: Marks, dtype: float64

# %%
sns.barplot(data=df, x="Gender", y="Marks", estimator="mean")
plt.title("Average Marks by Gender")
plt.show()

# %%
sns.scatterplot(data=df, x="Internet_Usage_Hours", y="Marks")
plt.title("Internet Usage Hours vs Marks")
plt.show()

# %%
df["Internet_Usage_Hours"].corr(df["Marks"])
# Out:
# np.float64(0.05393706974461052)

# %%
#multivariate analysis 
#checking corelation for all numerical column
df.corr(numeric_only=True)
# Out:
#                       Student_ID       Age  Study_Hours  Attendance     Marks  \
# Student_ID              1.000000 -0.012462    -0.091832    0.119532  0.177599
# Age                    -0.012462  1.000000     0.116727   -0.031151 -0.155646
# Study_Hours            -0.091832  0.116727     1.000000   -0.059798 -0.009642
# Attendance              0.119532 -0.031151    -0.059798    1.000000 -0.037728
# Marks                   0.177599 -0.155646    -0.009642   -0.037728  1.000000
# Internet_Usage_Hours    0.134421  0.179490     0.032088    0.121421  0.053937
#
#                       Internet_Usage_Hours
# Student_ID                        0.134421
# Age                               0.179490
# Study_Hours                       0.032088
# Attendance                        0.121421
# Marks                             0.053937
# Internet_Usage_Hours              1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.barplot(
    data=df,
    x="Department",
    y="Marks",
    hue="Gender"
)
plt.title("Average Marks by Department and Gender")
plt.show()

# %%
sns.barplot(data=df, x="Department", y="Study_Hours")
plt.title("Average Study Hours by Department")
plt.show()

# %%
sns.countplot(data=df, x="Department", hue="Gender")

plt.title("Gender Distribution by Department")
plt.xlabel("Department")
plt.ylabel("Number of Students")
plt.show()

# %%
df['Department'].value_counts()
# Out:
# Department
# CS      29
# MECH    29
# IT      25
# ECE     17
# Name: count, dtype: int64

# %%
sns.barplot(
    data=df,
    x="Department",
    y="Study_Hours",
    hue="Gender"
)
plt.title("Average Study Hours by Department and Gender")
plt.show()

# %%
df["Gender"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
df["Department"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Student Distribution by Department")
plt.ylabel("")
plt.show()

# %%
import matplotlib.pyplot as plt
count = df["Department"].value_counts()
plt.bar(count.index, count.values)
plt.xlabel("Department")
plt.ylabel("Number of Students")
plt.title("Department-wise Student strength")
plt.show()
